# %%
names = [’周杰伦‘，’陈奕迅‘，周星驰]
scores = [95, 99, 100 ]

# %%
# dict_
d = {'Michale':95,'Bob':75,'Tracy':85}
d['Michale']
# 从第一个字找到最后一个字
# 书本的最前面的索引部分，形象理解
# hash？根据key进行哈希计算，结果唯一值的地址
# 没有顺序的

# %%
d['Adam'] = 67
d['Adam']
d['Jack'] = 90
d['Jack']
d['Jack'] = 88
d['Jack']
# Out:
# 88

# %%
# 初始化key：value ，动态的添加，代码一复杂，dict就不好掌握
# d['Thomas']
# dict in_
"Thomas" in d
print(d.get('Thomas'))
print(d.get('Thomas',-1))
print(d.get('Jack',-1))
# Out:
# None
# -1
# 88

# %%
# d.pop('Bob ')
# d

key = [1,2,3]
d[key] = 'a list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       1 # d.pop('Bob ')
#       2 # d
#       4 key = [1,2,3]
# ----> 5 d[key] = 'a list'
#
# TypeError: unhashable type: 'list'

# %%
# { }声明了一个set
s = {1,2,3}
s
# Out:
# {1, 2, 3}

# %%
s = set([1,2,3,2,5])
s
s.add(4)
s
s.remove(4)
s
# Out:
# {1, 2, 3, 5}

# %%
s1 = {1,2,3}
s2 = {2,3,4}
s1 & s2 #交集
s1 | s2 #并集
# Out:
# {1, 2, 3, 4}

# %%
a = ['c','b','a']
print(a.sort()) #可变对象，指向的还是原来的内存地址
a
# Out:
# None
# ['a', 'b', 'c']

# %%
str = 'abc'
print(str.replace('a','A'))
print(str)
# Out:
# Abc
# abc
